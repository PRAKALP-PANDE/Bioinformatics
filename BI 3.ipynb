# %%
# Importing Libraries import pandas as pd

import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df_train = pd.read_csv('/Users/sonavaneonkar/Downloads/train.csv')
print(df_train.shape)

df_test = pd.read_csv('/Users/sonavaneonkar/Downloads/test.csv')
print(df_test.shape)
# Out:
# (38, 7131)
# (34, 7131)

# %%
df_train.head()
# Out:
#    Unnamed: 0  AFFX-BioB-5_at  AFFX-BioB-M_at  AFFX-BioB-3_at  AFFX-BioC-5_at  \
# 0           0            -214            -153             -58              88
# 1           1            -139             -73              -1             283
# 2           2             -76             -49            -307             309
# 3           3            -135            -114             265              12
# 4           4            -106            -125             -76             168
#
#    AFFX-BioC-3_at  AFFX-BioDn-5_at  AFFX-BioDn-3_at  AFFX-CreX-5_at  \
# 0            -295             -558              199            -176
# 1            -264             -400             -330            -168
# 2            -376             -650               33            -367
# 3            -419             -585              158            -253
# 4            -230             -284                4            -122
#
#    AFFX-CreX-3_at  ...  U58516_at  U73738_at  X06956_at  X16699_at  X83863_at  \
# 0             252  ...        511       -125        389        -37        793
# 1             101  ...        837        -36        442        -17        782
# 2             206  ...       1199         33        168         52       1138
# 3              49  ...        835        218        174       -110        627
# 4              70  ...        649         57        504        -26        250
#
#    Z17240_at  L49218_f_at  M71243_f_at  Z78285_f_at  cancer
# 0        329           36          191          -37       0
# 1        295           11           76          -14       0
# 2        777           41          228          -41       0
# 3        170          -50          126          -91       0
# 4        314           14           56          -25       0
#
# [5 rows x 7131 columns]

# %%
df_test.head()
# Out:
#    Unnamed: 0  AFFX-BioB-5_at  AFFX-BioB-M_at  AFFX-BioB-3_at  AFFX-BioC-5_at  \
# 0           0            -342            -200              41             328
# 1           1             -87            -248             262             295
# 2           2              22            -153              17             276
# 3           3            -243            -218            -163             182
# 4           4            -130            -177             -28             266
#
#    AFFX-BioC-3_at  AFFX-BioDn-5_at  AFFX-BioDn-3_at  AFFX-CreX-5_at  \
# 0            -224             -427             -656            -292
# 1            -226             -493              367            -452
# 2            -211             -250               55            -141
# 3            -289             -268             -285            -172
# 4            -170             -326             -222             -93
#
#    AFFX-CreX-3_at  ...  U58516_at  U73738_at  X06956_at  X16699_at  X83863_at  \
# 0             137  ...       1023         67        214       -135       1074
# 1             194  ...        529       -295        352        -67         67
# 2               0  ...        399         16        558         24        893
# 3              52  ...        277          6         81          2        722
# 4              10  ...        643         51        450        -46        612
#
#    Z17240_at  L49218_f_at  M71243_f_at  Z78285_f_at  cancer
# 0        475           48          168          -70       0
# 1        263          -33          -33          -21       0
# 2        297            6         1971          -42       0
# 3        170            0          510          -73       0
# 4        370           29          333          -19       0
#
# [5 rows x 7131 columns]

# %%
x_train = df_train.iloc[:, :-1]
y_train = df_train.iloc[:, -1:]

x_test = df_test.iloc[:, :-1]
y_test = df_test.iloc[:, -1:]

# %%
y_train.head()
# Out:
#    cancer
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# # Training the model

# %%
model = RandomForestClassifier(random_state = 0)
model.fit(x_train, y_train.values)
# Out:
# /var/folders/bw/fdws4hb55350qkgfkhtzp_gh0000gn/T/ipykernel_29172/1610722555.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x_train, y_train.values)
# RandomForestClassifier(random_state=0)

# %%
y_pred = model.predict(x_test)
accuracy_score(y_pred, y_test)
# Out:
# 0.6470588235294118

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[18,  2],
#        [10,  4]])
